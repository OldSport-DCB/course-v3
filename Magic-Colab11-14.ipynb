# %% [markdown]
# <a href="https://colab.research.google.com/github/OldSport-DCB/course-v3/blob/master/Magic-Colab11-14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests,json,os,time,bs4,shutil,re
colors = ['w','u','b','r','g']
types = ['creature','instant','sorcery','enchantment']

for color in colors:
    print("{0}=requests.get('https://api.scryfall.com/cards/search?q=id%3D{0}+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()".format(color))
    print("\n")
# Out:
# w=requests.get('https://api.scryfall.com/cards/search?q=id%3Dw+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()
#
#
# u=requests.get('https://api.scryfall.com/cards/search?q=id%3Du+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()
#
#
# b=requests.get('https://api.scryfall.com/cards/search?q=id%3Db+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()
#
#
# r=requests.get('https://api.scryfall.com/cards/search?q=id%3Dr+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()
#
#
# ...

# %%
w=requests.get('https://api.scryfall.com/cards/search?q=id%3Dw+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()


u=requests.get('https://api.scryfall.com/cards/search?q=id%3Du+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()


b=requests.get('https://api.scryfall.com/cards/search?q=id%3Db+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()


r=requests.get('https://api.scryfall.com/cards/search?q=id%3Dr+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()


g=requests.get('https://api.scryfall.com/cards/search?q=id%3Dg+-is%3Asplit+-is%3Atransform+border%3Ablack+not%3Adoublefaced+-t%3Aadventure+-t%3Aartifact+-t%3Atribal+legal%3Amodern+-t%3Alegendary+-t%3Aland').json()

listoflists = [w,u,b,r,g]

# %%
p='/content/drive/My Drive/Colab Notebooks/FastAI course/pictures'

# %%
"""%%time
artcropdict={}
for item in listoflists:
    print("next json in listoflists")
    print(item["data"][5]["name"])
    if item["has_more"]==True:
        one_nextjson = requests.get(item["next_page"]).json()
        if one_nextjson["has_more"]==True:
            two_nextjson = requests.get(one_nextjson["next_page"]).json()
            if two_nextjson["has_more"]==True:
                three_nextjson = requests.get(two_nextjson["next_page"]).json()
                if three_nextjson["has_more"]==True:
                    four_nextjson = requests.get(three_nextjson["next_page"]).json()
                    if four_nextjson["has_more"]==True:
                        five_nextjson = requests.get(four_nextjson["next_page"]).json()
                        if five_nextjson["has_more"]==True:
                            six_nextjson = requests.get(five_nextjson["next_page"]).json()
                            if six_nextjson["has_more"]==True:
                                seven_nextjson = requests.get(six_nextjson["next_page"]).json()
                                if seven_nextjson["has_more"]==True:
                                    eight_nextjson = requests.get(seven_nextjson["next_page"]).json()


                    
                
                
    listofjsons = [item,one_nextjson,two_nextjson,three_nextjson,four_nextjson,five_nextjson,six_nextjson,seven_nextjson,eight_nextjson]
    
    for item in listofjsons:
        print('next being added to dict, there are already ',len(artcropdict.values()))
        for card in item["data"]:
            artcropuri = card['image_uris']["art_crop"]
            cardname = str(card["colors"])+str(card["type_line"]+"---"+str(card["name"])+"--")+".jpg"
            artcropdict[cardname]=artcropuri"""
# Out:
# '%%time\nartcropdict={}\nfor item in listoflists:\n    print("next json in listoflists")\n    print(item["data"][5]["name"])\n    if item["has_more"]==True:\n        one_nextjson = requests.get(item["next_page"]).json()\n        if one_nextjson["has_more"]==True:\n            two_nextjson = requests.get(one_nextjson["next_page"]).json()\n            if two_nextjson["has_more"]==True:\n                three_nextjson = requests.get(two_nextjson["next_page"]).json()\n                if three_nextjson["has_more"]==True:\n                    four_nextjson = requests.get(three_nextjson["next_page"]).json()\n                    if four_nextjson["has_more"]==True:\n                        five_nextjson = requests.get(four_nextjson["next_page"]).json()\n                        if five_nextjson["has_more"]==True:\n                            six_nextjson = requests.get(five_nextjson["next_page"]).json()\n                            if six_nextjson["has_more"]==True:\n                          
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# /content/drive/My Drive/Colab Notebooks/FastAI course/pictures

# %%
"""%%time
i=0
for key,value in artcropdict.items():
    i+=1
    if i==150:
        print('next 150 done')
        i=0
    time.sleep(.08)
    response = requests.get((value[:-11]),stream=True)
    with open ('{0}/{1}'.format(p,key), 'wb') as out_file:
            shutil.copyfileobj(response.raw, out_file)
    del response
   """

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torch.nn.functional")

from fastai.vision import *
from fastai.metrics import error_rate

# %%
bs = 50
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart
path = '/content/drive/My Drive/Colab Notebooks/FastAI course/pictures'

path = Path(path)

# %%
fnames = get_image_files(path)
fnames[:5]
print(len(fnames))
# Out:
# 7790

# %%
np.random.seed(2)
cpat = r".+\['(\w).+\.jpg$" #color
tpat = r".+\](\w+)" #type

# %% [markdown]
# pat = r".+\](\w+)" #type
#
# pat = r".+\['(\w).+\.jpg$" #color
#
# ```
# # This is formatted as code
# ```

# %%
data = ImageDataBunch.from_name_re(path
                                  , fnames, cpat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# ['B', 'G', 'R', 'U', 'W']
# (5, 5)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
learn.fit_one_cycle(4)
learn.save('colors-stage-1')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.000636</td>
#       <td>1.524547</td>
#       <td>0.536585</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.482580</td>
#       <td>1.264172</td>
#       <td>0.510911</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.261184</td>
#       <td>1.227515</td>
#       <td>0.494223</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.170960</td>
#       <td>1.214431</td>
#       <td>0.484596</td>
#       <td>03:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.269169</td>
#       <td>1.331542</td>
#       <td>0.500642</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.256981</td>
#       <td>1.317581</td>
#       <td>0.503209</td>
#       <td>03:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.103940</td>
#       <td>1.200827</td>
#       <td>0.456354</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.826663</td>
#       <td>1.185770</td>
#       <td>0.440308</td>
#       <td>03:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
 
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)


interp.plot_top_losses(9, figsize=(15,11))

interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

interp.most_confused(min_val=2)
# Out:
# [('U', 'W', 61),
#  ('R', 'W', 58),
#  ('B', 'G', 57),
#  ('W', 'U', 50),
#  ('B', 'W', 49),
#  ('B', 'R', 43),
#  ('B', 'U', 43),
#  ('U', 'G', 40),
#  ('W', 'R', 40),
#  ('W', 'B', 39),
#  ('R', 'B', 38),
#  ('G', 'B', 37),
#  ('U', 'B', 36),
#  ('W', 'G', 33),
#  ('R', 'G', 30),
#  ('G', 'U', 25),
#  ('R', 'U', 23),
#  ('U', 'R', 23),
#  ('G', 'W', 16),
#  ('G', 'R', 14)]

# %% [markdown]
# Part 2 - cardtype classifier with Resnet 101

# %%
data2 = ImageDataBunch.from_name_re(path
                                  , fnames, tpat, ds_tfms=get_transforms(), size=224, bs=bs
                                  ).normalize(imagenet_stats)

# %%
learner2 = cnn_learner(data2, models.resnet101, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/checkpoints/resnet101-5d3b4d8f.pth
# 100%|██████████| 170M/170M [00:03<00:00, 57.4MB/s]

# %%
learner2.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.173971</td>
#       <td>1.600995</td>
#       <td>0.490372</td>
#       <td>03:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.368011</td>
#       <td>1.188134</td>
#       <td>0.536585</td>
#       <td>03:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.140492</td>
#       <td>1.144234</td>
#       <td>0.563543</td>
#       <td>03:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.020309</td>
#       <td>1.121909</td>
#       <td>0.564185</td>
#       <td>03:21</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner2.unfreeze
learner2.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.107648</td>
#       <td>1.196676</td>
#       <td>0.544288</td>
#       <td>03:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.136310</td>
#       <td>1.165118</td>
#       <td>0.555841</td>
#       <td>03:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.059375</td>
#       <td>1.128550</td>
#       <td>0.566110</td>
#       <td>03:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.967295</td>
#       <td>1.124982</td>
#       <td>0.570603</td>
#       <td>03:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learner2)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)


interp.plot_top_losses(9, figsize=(15,11))

interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

interp.most_confused(min_val=2)
# Out:
# [('Enchantment', 'Creature', 162),
#  ('Instant', 'Creature', 152),
#  ('Sorcery', 'Creature', 126),
#  ('Enchantment', 'Sorcery', 34),
#  ('Creature', 'Sorcery', 32),
#  ('Sorcery', 'Instant', 28),
#  ('Instant', 'Sorcery', 25),
#  ('Enchantment', 'Instant', 24),
#  ('Creature', 'Instant', 23),
#  ('Sorcery', 'Enchantment', 22),
#  ('Creature', 'Enchantment', 19),
#  ('Instant', 'Enchantment', 17),
#  ('Snow', 'Creature', 4)]
